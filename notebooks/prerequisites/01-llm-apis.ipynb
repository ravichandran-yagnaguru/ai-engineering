# %% [markdown]
# Load Environment

# %%
from dotenv import load_dotenv
import os

load_dotenv("../../.env")
# Out:
# True

# %% [markdown]
# ## OpenAI Client

# %%
import openai

response  = openai.chat.completions.create(
  model="gpt-5-nano",
  messages=[
        {"role": "system", "content": "You are a helpful assistant."},
        {"role": "user", "content": "Who won the world series in 2020?"},
    ]
)
print(response.choices[0].message.content)
# Out:
# The Los Angeles Dodgers won the 2020 World Series, defeating the Tampa Bay Rays 4 games to 2. Corey Seager was the World Series MVP.

# %%
response.usage
# Out:
# CompletionUsage(completion_tokens=426, prompt_tokens=26, total_tokens=452, completion_tokens_details=CompletionTokensDetails(accepted_prediction_tokens=0, audio_tokens=0, reasoning_tokens=384, rejected_prediction_tokens=0), prompt_tokens_details=PromptTokensDetails(audio_tokens=0, cached_tokens=0))

# %%
import openai

response  = openai.chat.completions.create(
  model="gpt-5-nano",
  messages=[
        {"role": "system", "content": "You are a helpful assistant."},
        {"role": "user", "content": "Who won the world series in 2020?"},
    ],
    reasoning_effort="minimal"
)
print(response.choices[0].message.content)
# Out:
# The Los Angeles Dodgers won the World Series in 2020. They defeated the Tampa Bay Rays, four games to two, in the best-of-seven series. It was the Dodgers' seventh World Series title in franchise history, and their first since 1988.

# %%
response.usage
# Out:
# CompletionUsage(completion_tokens=62, prompt_tokens=26, total_tokens=88, completion_tokens_details=CompletionTokensDetails(accepted_prediction_tokens=0, audio_tokens=0, reasoning_tokens=0, rejected_prediction_tokens=0), prompt_tokens_details=PromptTokensDetails(audio_tokens=0, cached_tokens=0))

# %% [markdown]
# ### Google Genai Client

# %%
from google import genai

gemini_client = genai.Client(api_key=os.getenv("GOOGLE_API_KEY"))

response = gemini_client.models.generate_content(
    model="gemini-2.5-flash",
    contents=["you are a maths teacher, what is 2+2"]
)

print(response.text)
# Out:
# Hello there!
#
# That's an excellent question to start with.
#
# The answer to **2 + 2** is **4**.
#
# Keep up the great work!
